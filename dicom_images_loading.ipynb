# %% [markdown]
# <a href="https://colab.research.google.com/github/snitin08/Navya-Healthcare-hackathon/blob/master/dicom_images_loading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %env PYTHONPATH=
# Out:
# env: PYTHONPATH=

# %%
# %%bash
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-4.5.4-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local
# wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX
# Out:
# PREFIX=/usr/local
# installing: python-3.6.5-hc3d631a_2 ...
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libstdcxx-ng-7.2.0-hdf63c60_3 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: ncurses-6.1-hf484d3e_0 ...
# installing: openssl-1.0.2o-h20670df_0 ...
# installing: tk-8.6.7-hc745277_3 ...
# installing: xz-5.2.4-h14c3975_4 ...
# installing: yaml-0.1.7-had09818_2 ...
# installing: zlib-1.2.11-ha838bed_2 ...
# installing: libedit-3.1.20170329-h6b74fdf_2 ...
# installing: readline-7.0-ha6073c6_4 ...
# installing: sqlite-3.23.1-he433501_0 ...
# installing: asn1crypto-0.24.0-py36_0 ...
# installing: certifi-2018.4.16-py36_0 ...
# installing: chardet-3.0.4-py36h0f667ec_1 ...
# installing: idna-2.6-py36h82fb2a8_1 ...
# installing: pycosat-0.6.3-py36h0a5515d_0 ...
# installing: pycparser-2.18-py36hf9f622e_1 ...
# installing: pysocks-1.6.8-py36_0 ...
# ...

# %%
# %%bash
# conda install --channel defaults conda python=3.6 --yes
# conda update --channel defaults --all --yes
# Out:
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#     - python=3.6
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pysocks-1.7.1              |           py36_0          30 KB
#     _libgcc_mutex-0.1          |             main           3 KB
#     conda-package-handling-1.6.1|   py36h7b6447c_0         886 KB
#     libstdcxx-ng-9.1.0         |       hdf63c60_0         4.0 MB
#     python-3.6.10              |       h7579374_2        33.9 MB
#     conda-4.8.3                |           py36_0         3.0 MB
#     readline-8.0               |       h7b6447c_0         428 KB
#     ld_impl_linux-64-2.33.1    |       h53a641e_7         645 KB
#     pycparser-2.20             |             py_2          94 KB
#     cffi-1.14.0                |   py36he30daa8_1         226 KB
# ...

# %%
import sys
_ = (sys.path
        .append("/usr/local/lib/python3.6/site-packages"))

# %%
# !conda install -c anaconda pillow -y
# !conda install -c anaconda numpy -y
# !conda install -c conda-forge matplotlib -y
# !conda install -c conda-forge pydicom -y
# !conda install -c conda-forge gdcm -y
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - pillow
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2020.6.24  |                0         133 KB  anaconda
#     certifi-2020.6.20          |           py36_0         160 KB  anaconda
#     conda-4.8.3                |           py36_0         3.0 MB  anaconda
#     freetype-2.10.2            |       h5ab3b9f_0         915 KB  anaconda
#     jpeg-9b                    |       habf39ab_1         247 KB  anaconda
#     lcms2-2.11                 |       h396b838_0         419 KB  anaconda
#     libpng-1.6.37              |       hbc83047_0         364 KB  anaconda
#     libtiff-4.1.0              |       h2733197_1         607 KB  anaconda
#     lz4-c-1.9.2                |       he6710b0_0         235 KB  anaconda
# ...

# %%
# !python --version
# !conda --version
# !which conda
# Out:
# Python 3.6.10 :: Anaconda, Inc.
# conda 4.8.3
# /usr/local/bin/conda

# %%
# !which python
# Out:
# /usr/local/bin/python

# %%
# !pip install -U gensim
# Out:
# ...
#      |████████████████████████████████| 24.2 MB 98 kB/s
# ...
#   Attempting uninstall: gensim
#     Found existing installation: gensim 3.8.0
#     Uninstalling gensim-3.8.0:
#       Successfully uninstalled gensim-3.8.0
# ...

# %%
import pydicom as dicom
import matplotlib.pyplot as plt

image_path ='/content/drive/'+'My Drive'+'/MR Brain - Sample Test Data/'+'1'+'/ExportFile_0_0.dcm'
ds = dicom.dcmread(image_path)

plt.imshow(ds.pixel_array)

# %%
from gensim.utils import simple_preprocess
from smart_open import smart_open
import gensim.corpora as corpora
import os
person_file_path = "/content/drive/My Drive/MR Brain - Sample Test Data/1/P Details.txt"
text = [line.split(':')[1][:-1] for line in open(person_file_path,"r")]
text
# Out:
# [' M', ' 29Y0M0W0D', ' BRAIN', ' Norma']

# %%
report_file_path = "/content/drive/My Drive/MR Brain - Sample Test Data/1/Report.txt"
dictionary = corpora.Dictionary(simple_preprocess(line, deacc=True) for line in open(report_file_path, encoding='utf-8'))
for word in dictionary.token2id:
  print(word)
# Out:
# brain
# mri
# of
# plain
# the
# axial
# coronal
# dwi
# flair
# gre
# sagittal
# sequences
# findings
# mr
# and
# cerebral
# characteristics
# depict
# grey
# hemispheres
# matter
# normal
# signal
# white
# lesion
# no
# occupying
# seen
# space
# effect
# mass
# midline
# noted
# or
# shift
# are
# cisterns
# ventricles
# cerebellum
# show
# angle
# bilaterally
# cerebello
# evidence
# in
# pontine
# region
# arteries
# flow
# intracranial
# voids
# left
# maxillary
# polyp
# small
# paranasal
# rest
# sinuses
# bilateral
# contents
# orbits
# their
# unremarkable
# impression
# study
